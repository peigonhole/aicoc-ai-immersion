# %% [markdown]
# # Build your custom image classifier using FastAI and WML-CE

# %% [markdown]
# This notebook was copied and modified for this lab from this source https://github.com/fastai/course-v3
#
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# !pwd
# Out:
# /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
# For Using GPU's
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ## About our Class Environment

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.3](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.
#
# For this class, we are using WML-CE running in the Worldwide Client Experience Center Cloud, or CECC for short.  To access and environment, simply browse to this website and request a Power8 or Power9 environment.
#
# https://www.ibm.com/it-infrastructure/services/cecc-portal/web/Catalog
#
# * Note : To get PowerAI up and running we have a special setup script in our github repo ...
#
# https://github.ibm.com/vanstee/aicoc-ai-immersion/blob/master/FastAI/setup_fastai.sh

# %%
# export
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
import os

# utility print function
def nprint(mystring) :
    print("**{}** : {}".format(sys._getframe(1).f_code.co_name,mystring))

# %% [markdown]
# ## Project Configuration
#
# This data structure below will hold all the settings for our class.  Its handy to have a simple dictionary contain all your project settings to keep organized.  We have include an override capability to these default settings so that you can customize your project.

# %%
def getconfig(cfg_in={},base_dir="."):
    cfg = {}
    cfg["bs"] = 16
    cfg["base_dir"]  = base_dir
    cfg["image_dir"] = base_dir + "/class_images"
    cfg["classes"] = ["cars","busses","trucks"]
    cfg["num_images"] = {"train":200,"valid":20,"test":20}
    cfg["d_partitions"] = list(cfg["num_images"].keys())                 
    cfg["jpeginfo"] =base_dir + "/jpeginfo"
   
    # overwrite configs if passed
    for (k,v) in cfg_in.items() :
        nprint("Overriding Config {}:{} with {}".format(k,cfg[k],v))
        cfg[k] = v
    return cfg

# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# Here we are going to build our own dataset !!  Think of 3 categories you would like to classify images.  In this example, we will use
# * busses
# * trucks
# * cars
#
# We will use an open source tool called *googliser* to download our images from google images.
#
# For a Covid-19 based example you could make your classes something like
# * "people wearing masks"
# * "people posing street"

# %%
#################################################################################################
# @@ Students : Customize this cell with your custom classes for image classification
################################################################################################

# Overrides for lab

mycfg = {
    "classes":["people wearing masks","people posing street","people skateboarding","people on bikes"],  ## <<- CLASS Enter your search terms here 
    "d_partitions":["train"],
}

base_dir=!pwd
base_dir=base_dir[0]

print("Base project directory : {}".format(base_dir))
cfg=getconfig(mycfg, base_dir)
# Out:
# Base project directory : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA
# **getconfig** : Overriding Config classes:['cars', 'busses', 'trucks'] with ['people wearing masks', 'people posing street', 'people skateboarding', 'people on bikes']
# **getconfig** : Overriding Config d_partitions:['train', 'valid', 'test'] with ['train']

# %% [markdown]
# ## Make Some Directories to hold our data
#
# FastAI is very flexible and help you label your image data in all sorts of ways.  You might have a bunch of images and a csv file with the labels.  You might have your images organized by folder with the folder name being the labels.
#
# To see all the supported methods check out this link..
# https://docs.fast.ai/vision.data.html#ImageDataBunch.from_folder
#
# For our class, we are going to organize our data by folder into something like this..
#
# ![image.png](attachment:image.png)

# %%
# Helpers to make directories
def class_folder_name(base,d_part,cls) :
    return base+"/"+d_part+"/"+ cls.replace(" ","_")

def makeDirIfNotExist(directory) :
    if not os.path.exists(directory):  
        nprint("Making directory {}".format(directory))
        os.makedirs(directory) 
    else :
        nprint("Directory {} already exists .. ".format(directory))

# Build directory hierarchy
#   [train|valid|test ]
#    -----------------> [class1 | class2 | class...]
for d_part in cfg["d_partitions"] :
    for cls in cfg["classes"] :
        directory=class_folder_name(cfg['image_dir'],d_part,cls)
        makeDirIfNotExist(directory)
# Out:
# **makeDirIfNotExist** : Making directory /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_wearing_masks
# **makeDirIfNotExist** : Making directory /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_posing_street
# **makeDirIfNotExist** : Making directory /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_skateboarding
# **makeDirIfNotExist** : Making directory /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_on_bikes

# %% [markdown]
# ## Install Googliser here.
# This handy utility will download our images from google images.  We will clone the repo from git.

# %%
# install googliser
def install_googliser():
    googliser_directory = cfg['base_dir']+"/googliser"
    if not os.path.exists(googliser_directory):  
        nprint("Installing Googliser here : {} ".format(googliser_directory))
        os.chdir(cfg['base_dir'])
        # !git clone https://github.com/teracow/googliser
    else :
        nprint("Googliser already installed here : {} ".format(googliser_directory))

    googliser = cfg['base_dir']+"/googliser/googliser.sh"

    return googliser 
googliser = install_googliser()
# !ls {googliser}
# Out:
# **install_googliser** : Installing Googliser here : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser
# Cloning into 'googliser'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 2692 (delta 41), reused 47 (delta 21), pack-reused 2622
# Receiving objects: 100% (2692/2692), 5.28 MiB | 0 bytes/s, done.
# Resolving deltas: 100% (1639/1639), done.
# /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser/googliser.sh

# %% [markdown]
# ## How many images should we grab ?
#
# Luckily not too many.. it always depends on the project, but we are going to use a pre-training deep learning network when we perform training.  Since that network was already trained on over 1 million images, we don't need to supply too many for our task.  This is why transfer learning is so powerful!

# %%
cfg['num_images']
# Out:
# {'train': 200, 'valid': 20, 'test': 20}

# %%
# The code below will download files to train folder only to avoid duplicate downloads.  
# We then move a few files over.  This can be done manually or programatically.  For our example
# we will let FastAI do the work for us!

def download_images(cfg):
    utility_dir = cfg['base_dir']
    for d_p in cfg["d_partitions"] : # train only for now ..
        for cls in cfg["classes"] :
            current_dir =class_folder_name(cfg['image_dir'],d_p,cls)
            #os.chdir(current_dir)
            os.chdir(utility_dir)
            command = googliser + \
                      " --o {}".format(current_dir) +\
                      " --phrase \"{}\"".format(cls) + \
                      " --parallel 50 --upper-size 500000 --lower-size 2000 " + \
                      " -n {}".format(cfg['num_images'][d_p]) + \
                      " --format jpg --timeout 15 --safesearch-off "
            nprint(command)
            # !{command}
    nprint("Downloads complete!")
download_images(cfg)

# This will take ~5 mins depending on how many classes / images we are grabbing...
# Out:
# **download_images** : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser/googliser.sh --o /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_wearing_masks --phrase "people wearing masks" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:110987
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 68
#  download: 0/68 images OK0/68 images OK, 1/50 are in progress0/68 images OK, 2/50 are in progress0/68 images OK, 3/50 are in progress0/68 images OK, 4/50 are in progress0/68 images OK, 5/50 are in progress0/68 images OK, 6/50 are in progress0/68 images OK, 6/50 are in progress and 1 have failed0/68 images OK, 7/50 are in progress and 1 have failed0/68 images OK, 8/50 are in progress and 1 have failed0/68 images OK, 9/50 are in progress and 1 have failed0/68 images OK, 10/50 are in progress and 2 have faile0/68 images OK, 11/50 are in progress and 2 have faile0/68 images OK, 12/50 are in progress and 2 have faile1/68 images OK, 13/50 are in progress and 2 have faile1/68 images OK, 14/50 are in progress and 3 have faile1/68 images OK, 15/50 are in progress and 3 have faile1/68 images OK, 16/50 are in progress and 4 have faile1/68 images OK, 17/50 are in progress and 4 have faile2/68 images OK, 18/50 are in progress and 4 have faile2/68 images OK, 19/50 are in progress and 4 have faile2/68 images OK, 20/50 are in progress and 4 have faile3/68 images OK, 20/50 are in progress and 4 have faile5/68 images OK, 19/50 are in progress and 4 have faile6/68 images OK, 20/50 are in progress and 4 have faile6/68 images OK, 21/50 are in progress and 4 have faile6/68 images OK, 22/50 are in progress and 4 have faile6/68 images OK, 23/50 are in progress and 4 have faile7/68 images OK, 23/50 are in progress and 4 have faile8/68 images OK, 23/50 are in progress and 4 have faile8/68 images OK, 24/50 are in progress and 4 have faile8/68 images OK, 24/50 are in progress and 5 have faile9/68 images OK, 24/50 are in progress and 5 have faile11/68 images OK, 23/50 are in progress and 5 have failed11/68 images OK, 24/50 are in progress and 5 have failed11/68 images OK, 25/50 are in progress and 5 have failed11/68 images OK, 26/50 are in progress and 5 have failed12/68 images OK, 25/50 are in progress and 6 have failed12/68 images OK, 25/50 are in progress and 7 have failed12/68 images OK, 26/50 are in progress and 7 have failed14/68 images OK, 24/50 are in progress and 8 have failed14/68 images OK, 25/50 are in progress and 8 have failed14/68 images OK, 26/50 are in progress and 8 have failed14/68 images OK, 25/50 are in progress and 10 have faile15/68 images OK, 25/50 are in progress and 10 have faile15/68 images OK, 26/50 are in progress and 10 have faile17/68 images OK, 25/50 are in progress and 10 have faile18/68 images OK, 24/50 are in progress and 11 have faile19/68 images OK, 24/50 are in progress and 11 have faile21/68 images OK, 23/50 are in progress and 11 have faile21/68 images OK, 23/50 are in progress and 12 have faile21/68 images OK, 24/50 are in progress and 12 have faile21/68 images OK, 25/50 are in progress and 12 have faile22/68 images OK, 25/50 are in progress and 12 have faile22/68 images OK, 26/50 are in progress and 14 have faile23/68 images OK, 22/50 are in progress and 16 have faile23/68 images OK, 23/50 are in progress and 16 have faile24/68 images OK, 22/50 are in progress and 17 have faile24/68 images OK, 23/50 are in progress and 17 have faile25/68 images OK, 23/50 are in progress and 17 have faile26/68 images OK, 24/50 are in progress and 18 have faile26/68 images OK, 23/50 are in progress and 18 have faile27/68 images OK, 24/50 are in progress and 18 have faile27/68 images OK, 23/50 are in progress and 18 have faile27/68 images OK, 21/50 are in progress and 20 have faile28/68 images OK, 20/50 are in progress and 20 have faile29/68 images OK, 19/50 are in progress and 20 have faile30/68 images OK, 18/50 are in progress and 20 have faile30/68 images OK, 18/50 are in progress and 21 have faile30/68 images OK, 17/50 are in progress and 21 have faile30/68 images OK, 16/50 are in progress and 22 have faile30/68 images OK, 15/50 are in progress and 23 have faile31/68 images OK, 14/50 are in progress and 23 have faile32/68 images OK, 13/50 are in progress and 23 have faile33/68 images OK, 12/50 are in progress and 23 have faile33/ ...
# **download_images** : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser/googliser.sh --o /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_posing_street --phrase "people posing street" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:144673
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 86
#  download: 0/86 images OK0/86 images OK, 1/50 are in progress0/86 images OK, 2/50 are in progress0/86 images OK, 3/50 are in progress0/86 images OK, 4/50 are in progress0/86 images OK, 5/50 are in progress0/86 images OK, 6/50 are in progress0/86 images OK, 7/50 are in progress0/86 images OK, 8/50 are in progress0/86 images OK, 9/50 are in progress0/86 images OK, 10/50 are in progres0/86 images OK, 11/50 are in progres0/86 images OK, 12/50 are in progres1/86 images OK, 12/50 are in progres2/86 images OK, 12/50 are in progres3/86 images OK, 12/50 are in progres3/86 images OK, 13/50 are in progres3/86 images OK, 14/50 are in progres3/86 images OK, 15/50 are in progres4/86 images OK, 16/50 are in progres5/86 images OK, 15/50 are in progres5/86 images OK, 16/50 are in progres7/86 images OK, 15/50 are in progres7/86 images OK, 16/50 are in progres7/86 images OK, 17/50 are in progres8/86 images OK, 17/50 are in progres9/86 images OK, 17/50 are in progres9/86 images OK, 17/50 are in progress and 1 have faile9/86 images OK, 18/50 are in progress and 1 have faile9/86 images OK, 19/50 are in progress and 1 have faile11/86 images OK, 18/50 are in progress and 1 have failed13/86 images OK, 18/50 are in progress and 2 have failed14/86 images OK, 15/50 are in progress and 3 have failed15/86 images OK, 15/50 are in progress and 3 have failed15/86 images OK, 16/50 are in progress and 3 have failed15/86 images OK, 17/50 are in progress and 3 have failed16/86 images OK, 17/50 are in progress and 3 have failed16/86 images OK, 18/50 are in progress and 3 have failed18/86 images OK, 17/50 are in progress and 3 have failed18/86 images OK, 18/50 are in progress and 3 have failed18/86 images OK, 19/50 are in progress and 3 have failed20/86 images OK, 18/50 are in progress and 3 have failed21/86 images OK, 18/50 are in progress and 3 have failed21/86 images OK, 19/50 are in progress and 3 have failed23/86 images OK, 18/50 are in progress and 3 have failed23/86 images OK, 19/50 are in progress and 3 have failed24/86 images OK, 18/50 are in progress and 5 have failed26/86 images OK, 17/50 are in progress and 5 have failed26/86 images OK, 16/50 are in progress and 6 have failed26/86 images OK, 17/50 are in progress and 6 have failed27/86 images OK, 17/50 are in progress and 6 have failed27/86 images OK, 18/50 are in progress and 6 have failed27/86 images OK, 19/50 are in progress and 6 have failed27/86 images OK, 20/50 are in progress and 6 have failed27/86 images OK, 21/50 are in progress and 6 have failed28/86 images OK, 21/50 are in progress and 6 have failed30/86 images OK, 20/50 are in progress and 6 have failed30/86 images OK, 21/50 are in progress and 6 have failed31/86 images OK, 19/50 are in progress and 8 have failed32/86 images OK, 19/50 are in progress and 8 have failed33/86 images OK, 20/50 are in progress and 8 have failed33/86 images OK, 19/50 are in progress and 9 have failed33/86 images OK, 20/50 are in progress and 9 have failed35/86 images OK, 19/50 are in progress and 9 have failed36/86 images OK, 19/50 are in progress and 10 have faile39/86 images OK, 17/50 are in progress and 10 have faile40/86 images OK, 16/50 are in progress and 10 have faile41/86 images OK, 16/50 are in progress and 10 have faile41/86 images OK, 17/50 are in progress and 10 have faile44/86 images OK, 16/50 are in progress and 10 have faile45/86 images OK, 16/50 are in progress and 10 have faile47/86 images OK, 15/50 are in progress and 10 have faile47/86 images OK, 16/50 are in progress and 10 have faile49/86 images OK, 15/50 are in progress and 10 have faile50/86 images OK, 16/50 are in progress and 10 have faile51/86 images OK, 15/50 are in progress and 10 have faile53/86 images OK, 14/50 are in progress and 10 have faile53/86 images OK, 15/50 are in progress and 10 have faile53/86 images OK, 16/50 are in progress and 10 have faile53/86 images OK, 17/50 are in progress and 10 have faile55/86 images OK, 17/50 are in progress and 10 have faile56/86 images OK, 16/5 ...
# 68/86 images OK, 7/50 are in progress and 11 have failed69/86 images OK, 6/50 are in progress and 11 have failed71/86 images OK, 5/50 are in progress and 11 have failed71/86 images OK, 4/50 are in progress and 11 have failed71/86 images OK, 3/50 are in progress and 12 have failed72/86 images OK, 2/50 are in progress and 12 have failed73/86 images OK, 1/50 are in progress and 12 have failed73/86 images OK and 13 failed                           links list exhausted!
# **download_images** : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser/googliser.sh --o /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_skateboarding --phrase "people skateboarding" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:111927
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 96
#  download: 0/96 images OK0/96 images OK, 1/50 are in progress0/96 images OK, 2/50 are in progress0/96 images OK, 3/50 are in progress0/96 images OK, 4/50 are in progress0/96 images OK, 5/50 are in progress0/96 images OK, 6/50 are in progress0/96 images OK, 7/50 are in progress0/96 images OK, 8/50 are in progress0/96 images OK, 9/50 are in progress0/96 images OK, 10/50 are in progres0/96 images OK, 10/50 are in progress and 1 have faile0/96 images OK, 11/50 are in progress and 1 have faile0/96 images OK, 12/50 are in progress and 1 have faile1/96 images OK, 12/50 are in progress and 1 have faile1/96 images OK, 13/50 are in progress and 1 have faile1/96 images OK, 14/50 are in progress and 1 have faile1/96 images OK, 15/50 are in progress and 1 have faile1/96 images OK, 16/50 are in progress and 1 have faile3/96 images OK, 16/50 are in progress and 1 have faile4/96 images OK, 14/50 are in progress and 2 have faile4/96 images OK, 15/50 are in progress and 2 have faile5/96 images OK, 15/50 are in progress and 2 have faile6/96 images OK, 15/50 are in progress and 2 have faile6/96 images OK, 14/50 are in progress and 4 have faile7/96 images OK, 14/50 are in progress and 4 have faile7/96 images OK, 15/50 are in progress and 4 have faile7/96 images OK, 16/50 are in progress and 4 have faile7/96 images OK, 16/50 are in progress and 5 have faile8/96 images OK, 16/50 are in progress and 5 have faile9/96 images OK, 16/50 are in progress and 5 have faile9/96 images OK, 17/50 are in progress and 5 have faile9/96 images OK, 18/50 are in progress and 5 have faile9/96 images OK, 19/50 are in progress and 5 have faile9/96 images OK, 20/50 are in progress and 5 have faile10/96 images OK, 20/50 are in progress and 5 have failed10/96 images OK, 21/50 are in progress and 5 have failed12/96 images OK, 22/50 are in progress and 5 have failed13/96 images OK, 20/50 are in progress and 5 have failed14/96 images OK, 20/50 are in progress and 5 have failed14/96 images OK, 21/50 are in progress and 5 have failed15/96 images OK, 20/50 are in progress and 6 have failed15/96 images OK, 21/50 are in progress and 6 have failed15/96 images OK, 22/50 are in progress and 6 have failed15/96 images OK, 23/50 are in progress and 6 have failed15/96 images OK, 24/50 are in progress and 6 have failed16/96 images OK, 24/50 are in progress and 6 have failed16/96 images OK, 25/50 are in progress and 6 have failed16/96 images OK, 26/50 are in progress and 7 have failed17/96 images OK, 25/50 are in progress and 7 have failed19/96 images OK, 24/50 are in progress and 7 have failed19/96 images OK, 25/50 are in progress and 7 have failed21/96 images OK, 24/50 are in progress and 7 have failed21/96 images OK, 25/50 are in progress and 7 have failed22/96 images OK, 26/50 are in progress and 7 have failed23/96 images OK, 25/50 are in progress and 7 have failed24/96 images OK, 24/50 are in progress and 8 have failed25/96 images OK, 24/50 are in progress and 8 have failed28/96 images OK, 23/50 are in progress and 8 have failed30/96 images OK, 21/50 are in progress and 8 have failed31/96 images OK, 20/50 are in progress and 9 have failed31/96 images OK, 20/50 are in progress and 10 have faile32/96 images OK, 21/50 are in progress and 10 have faile33/96 images OK, 20/50 are in progress and 10 have faile34/96 images OK, 20/50 are in progress and 10 have faile35/96 images OK, 20/50 are in progress and 10 have faile35/96 images OK, 21/50 are in progress and 10 have faile35/96 images OK, 22/50 are in progress and 10 have faile35/96 images OK, 22/50 are in progress and 11 have faile35/96 images OK, 23/50 are in progress and 11 have faile35/96 images OK, 24/50 are in progress and 11 have faile35/96 images OK, 25/50 are in progress and 11 have faile36/96 images OK, 25/50 are in progress and 11 have faile37/96 images OK, 26/50 are in progress and 11 have faile38/96 images OK, 25/50 are in progress and 11 have faile38/96 images OK, 26/50 are in progress and 11 have faile38/96 images OK, 27/50  ...
# 49/96 images OK, 26/50 are in progress and 17 have faile51/96 images OK, 24/50 are in progress and 19 have faile52/96 images OK, 23/50 are in progress and 19 have faile53/96 images OK, 23/50 are in progress and 19 have faile54/96 images OK, 23/50 are in progress and 19 have faile54/96 images OK, 22/50 are in progress and 20 have faile55/96 images OK, 21/50 are in progress and 20 have faile57/96 images OK, 19/50 are in progress and 20 have faile58/96 images OK, 18/50 are in progress and 20 have faile59/96 images OK, 18/50 are in progress and 20 have faile59/96 images OK, 17/50 are in progress and 20 have faile59/96 images OK, 16/50 are in progress and 21 have faile59/96 images OK, 16/50 are in progress and 22 have faile59/96 images OK, 15/50 are in progress and 22 have faile60/96 images OK, 14/50 are in progress and 22 have faile61/96 images OK, 13/50 are in progress and 22 have faile62/96 images OK, 13/50 are in progress and 22 have faile62/96 images OK, 12/50 are in progress and 22 have faile62/96 images OK, 11/50 are in progress and 23 have faile62/96 images OK, 10/50 are in progress and 24 have faile62/96 images OK, 9/50 are in progress and 25 have failed62/96 images OK, 8/50 are in progress and 26 have failed62/96 images OK, 7/50 are in progress and 27 have failed62/96 images OK, 6/50 are in progress and 28 have failed62/96 images OK, 6/50 are in progress and 29 have failed62/96 images OK, 5/50 are in progress and 29 have failed62/96 images OK, 4/50 are in progress and 30 have failed62/96 images OK, 3/50 are in progress and 31 have failed62/96 images OK, 2/50 are in progress and 32 have failed62/96 images OK, 2/50 are in progress and 33 have failed62/96 images OK, 1/50 are in progress and 33 have failed62/96 images OK and 34 failed                           links list exhausted!
# **download_images** : /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/googliser/googliser.sh --o /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_on_bikes --phrase "people on bikes" --parallel 50 --upper-size 500000 --lower-size 2000  -n 200 --format jpg --timeout 15 --safesearch-off
#  googliser.sh v:200212 PID:80545
#
#    Google: 0/10 web pages OK, 1/10 are in progres0/10 web pages OK, 2/10 are in progres0/10 web pages OK, 3/10 are in progres0/10 web pages OK, 4/10 are in progres0/10 web pages OK, 5/10 are in progres0/10 web pages OK, 6/10 are in progres0/10 web pages OK, 7/10 are in progres0/10 web pages OK, 8/10 are in progres0/10 web pages OK, 9/10 are in progres0/10 web pages OK, 10/10 are in progress10 web pages OK
#     links: 81
#  download: 0/81 images OK0/81 images OK, 1/50 are in progress0/81 images OK, 2/50 are in progress0/81 images OK, 3/50 are in progress0/81 images OK, 4/50 are in progress0/81 images OK, 5/50 are in progress0/81 images OK, 6/50 are in progress0/81 images OK, 7/50 are in progress0/81 images OK, 7/50 are in progress and 1 have failed0/81 images OK, 7/50 are in progress and 2 have failed1/81 images OK, 7/50 are in progress and 2 have failed1/81 images OK, 7/50 are in progress and 3 have failed1/81 images OK, 8/50 are in progress and 3 have failed1/81 images OK, 9/50 are in progress and 3 have failed1/81 images OK, 10/50 are in progress and 3 have faile1/81 images OK, 11/50 are in progress and 3 have faile2/81 images OK, 10/50 are in progress and 4 have faile4/81 images OK, 9/50 are in progress and 4 have failed4/81 images OK, 10/50 are in progress and 4 have faile4/81 images OK, 11/50 are in progress and 4 have faile7/81 images OK, 9/50 are in progress and 4 have failed7/81 images OK, 10/50 are in progress and 4 have faile7/81 images OK, 11/50 are in progress and 4 have faile7/81 images OK, 12/50 are in progress and 4 have faile7/81 images OK, 13/50 are in progress and 4 have faile8/81 images OK, 13/50 are in progress and 4 have faile8/81 images OK, 14/50 are in progress and 4 have faile9/81 images OK, 14/50 are in progress and 4 have faile9/81 images OK, 15/50 are in progress and 4 have faile9/81 images OK, 16/50 are in progress and 4 have faile10/81 images OK, 16/50 are in progress and 4 have failed11/81 images OK, 16/50 are in progress and 4 have failed11/81 images OK, 17/50 are in progress and 4 have failed11/81 images OK, 18/50 are in progress and 4 have failed11/81 images OK, 18/50 are in progress and 5 have failed12/81 images OK, 19/50 are in progress and 5 have failed12/81 images OK, 20/50 are in progress and 5 have failed12/81 images OK, 21/50 are in progress and 5 have failed12/81 images OK, 22/50 are in progress and 6 have failed13/81 images OK, 21/50 are in progress and 6 have failed13/81 images OK, 22/50 are in progress and 6 have failed13/81 images OK, 23/50 are in progress and 6 have failed14/81 images OK, 22/50 are in progress and 7 have failed14/81 images OK, 23/50 are in progress and 7 have failed15/81 images OK, 22/50 are in progress and 8 have failed17/81 images OK, 20/50 are in progress and 9 have failed18/81 images OK, 20/50 are in progress and 9 have failed18/81 images OK, 21/50 are in progress and 10 have faile19/81 images OK, 20/50 are in progress and 10 have faile20/81 images OK, 19/50 are in progress and 11 have faile20/81 images OK, 20/50 are in progress and 11 have faile21/81 images OK, 18/50 are in progress and 13 have faile21/81 images OK, 19/50 are in progress and 13 have faile21/81 images OK, 20/50 are in progress and 13 have faile21/81 images OK, 21/50 are in progress and 13 have faile22/81 images OK, 21/50 are in progress and 13 have faile22/81 images OK, 22/50 are in progress and 13 have faile25/81 images OK, 21/50 are in progress and 13 have faile25/81 images OK, 22/50 are in progress and 13 have faile26/81 images OK, 22/50 are in progress and 13 have faile27/81 images OK, 22/50 are in progress and 13 have faile28/81 images OK, 21/50 are in progress and 14 have faile28/81 images OK, 22/50 are in progress and 14 have faile29/81 images OK, 22/50 are in progress and 14 have faile29/81 images OK, 22/50 are in progress and 15 have faile29/81 images OK, 23/50 are in progress and 15 have faile29/81 images OK, 24/50 are in progress and 15 have faile29/81 images OK, 24/50 are in progress and 16 have faile30/81 images OK, 25/50 are in progress and 16 have faile30/81 images OK, 26/50 are in progress and 17 have faile31/81 images OK, 25/50 are in progress and 17 have faile31/81 images OK, 25/50 are in progress and 18 have faile32/81 images OK, 25/50 are in progress and 18 have faile33/81 images OK, 24/50 are in progress and 19 have faile34/81 images OK, 24/50 are in progress and 19 have faile35/81 images OK ...
# 50/81 images OK, 9/50 are in progress and 22 have failed51/81 images OK, 8/50 are in progress and 22 have failed52/81 images OK, 7/50 are in progress and 22 have failed52/81 images OK, 7/50 are in progress and 23 have failed52/81 images OK, 6/50 are in progress and 23 have failed53/81 images OK, 5/50 are in progress and 23 have failed54/81 images OK, 4/50 are in progress and 23 have failed55/81 images OK, 3/50 are in progress and 23 have failed56/81 images OK, 2/50 are in progress and 23 have failed56/81 images OK, 1/50 are in progress and 24 have failed56/81 images OK and 25 failed                           links list exhausted!
# **download_images** : Downloads complete!

# %% [markdown]
# ## Clean up downloaded images that are not proper jpeg format ..

# %%
# clean with jpeginfo! 
def clean_up_bad_images(cfg):
    os.chdir(cfg['image_dir'])
    nprint("Search for Error files in {}......".format(cfg['image_dir']))
    # handle both jpg //jpeg files that are malformed
    for ext in ["jpg","jpeg"] :
        command = "find . -name \"*.{}\"".format(ext) + \
          " | xargs -i {}".format(cfg["jpeginfo"]) + \
          " -c {} | grep ERROR"
        nprint("Running command : {}".format(command))
        # !{command}
        nprint("Removing any error files listed above")
        command = command + ' | cut -d " " -f1 | xargs -i rm {} '
        nprint("Running command : {}".format(command))
        # !{command}
        nprint("Done")
    # get rid of png /webp
    for ext in ["png", "webp"]:
        command = "find . -name \"*.{}\"".format(ext) + \
            " | xargs -i rm -f {}"
        nprint("Running command : {}".format(command))
        # !{command}
        
clean_up_bad_images(cfg)

# find . -name "*.jpg," | xargs -i ./jpeginfo -c {}
# find . -name "*.jpg" | xargs -i ./jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# Out:
# **clean_up_bad_images** : Search for Error files in /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images......
# **clean_up_bad_images** : Running command : find . -name "*.jpg" | xargs -i /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo -c {} | grep ERROR
# xargs: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo: No such file or directory
# **clean_up_bad_images** : Removing any error files listed above
# **clean_up_bad_images** : Running command : find . -name "*.jpg" | xargs -i /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# xargs: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo: No such file or directory
# **clean_up_bad_images** : Done
# **clean_up_bad_images** : Running command : find . -name "*.jpeg" | xargs -i /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo -c {} | grep ERROR
# xargs: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo: No such file or directory
# **clean_up_bad_images** : Removing any error files listed above
# **clean_up_bad_images** : Running command : find . -name "*.jpeg" | xargs -i /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo -c {} | grep ERROR | cut -d " " -f1 | xargs -i rm {}
# xargs: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/jpeginfo: No such file or directory
# **clean_up_bad_images** : Done
# **clean_up_bad_images** : Running command : find . -name "*.png" | xargs -i rm -f {}
# **clean_up_bad_images** : Running command : find . -name "*.webp" | xargs -i rm -f {}

# %%
#path = untar_data(URLs.PETS); path
path = Path(cfg['image_dir'])

# %%
path.ls()
#cfg['image_dir']
# Out:
# [PosixPath('/gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train')]

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %% [markdown]
# ## Create Data Bunch
# Fastai has a number of methods to create a data bunch. Lets look at some of the documentation using **doc** function

# %%
#doc(ImageDataBunch)
doc(ImageDataBunch.from_folder)

# %%
# https://docs.fast.ai/vision.data.html#ImageDataBunch.from_folder
## Important, batch size should be set lower than the number of images you have
data = ImageDataBunch.from_folder(path=cfg['image_dir'],
                train="train",valid_pct=0.20,no_check=True,
                size=224,num_workers=4,bs=cfg["bs"]).normalize(imagenet_stats)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (170 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_skateboarding,people_skateboarding,people_skateboarding,people_skateboarding,people_skateboarding
# Path: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images;
#
# Valid: LabelList (42 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_skateboarding,people_posing_street,people_skateboarding,people_on_bikes,people_posing_street
# Path: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images;
#
# Test: None

# %%
data.show_batch(rows=4, figsize=(9,9))
#data.show_batch(figsize=(4,4))

# %%
data.label_list
# Out:
# LabelLists;
#
# Train: LabelList (170 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_skateboarding,people_skateboarding,people_skateboarding,people_skateboarding,people_skateboarding
# Path: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images;
#
# Valid: LabelList (42 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# people_skateboarding,people_posing_street,people_skateboarding,people_on_bikes,people_posing_street
# Path: /gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images;
#
# Test: None

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['people_on_bikes', 'people_posing_street', 'people_skateboarding', 'people_wearing_masks']
# (4, 4)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).

# %%
#create learner
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
# save pretrained model ..
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
# dont worry about the #na#, as long as we get a plot in the next section, great!
learn.lr_find() # num_it=36, stop_div=False
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-22-f0932330648e> in <module>
#       1 # dont worry about the #na#, as long as we get a plot in the next section, great!
# ----> 2 learn.lr_find() # num_it=36, stop_div=False
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, wd)
#      39     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      40     epochs = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 41     learn.fit(epochs, start_lr, callbacks=[cb], wd=wd)
#      42
#      43 def to_fp16(learn:Learner, loss_scale:float=None, max_noskip:int=1000, dynamic:bool=True, clip:float=None,
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     199         else: self.opt.lr,self.opt.wd = lr,wd
#     200         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 201         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     202
#     203     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      98             cb_handler.set_dl(learn.data.train_dl)
#      99             cb_handler.on_epoch_begin()
# --> 100             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     101                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     102                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      45         except Exception as e:
#      46             self.on_interrupt()
# ---> 47             raise e
#      48
#      49     def update(self, val):
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      39         if self.total != 0: self.update(0)
#      40         try:
# ---> 41             for i,o in enumerate(self.gen):
#      42                 if i >= self.total: break
#      43                 yield o
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     799             if len(self.task_info[self.rcvd_idx]) == 2:
#     800                 data = self.task_info.pop(self.rcvd_idx)[1]
# --> 801                 return self._process_data(data)
#     802
#     803             assert not self.shutdown and self.tasks_outstanding > 0
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#     844         self._try_put_index()
#     845         if isinstance(data, ExceptionWrapper):
# --> 846             data.reraise()
#     847         return data
#     848
#
# ~/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     367             # (https://bugs.python.org/issue2651), so we work around it.
#     368             msg = KeyErrorMessage(msg)
# --> 369         raise self.exc_type(msg)
#
# UnidentifiedImageError: Caught UnidentifiedImageError in DataLoader worker process 3.
# Original Traceback (most recent call last):
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/_utils/worker.py", line 178, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/data_block.py", line 651, in __getitem__
#     if self.item is None: x,y = self.x[idxs],self.y[idxs]
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/data_block.py", line 120, in __getitem__
#     if isinstance(idxs, Integral): return self.get(idxs)
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/vision/data.py", line 271, in get
#     res = self.open(fn)
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/vision/data.py", line 267, in open
#     return open_image(fn, convert_mode=self.convert_mode, after_open=self.after_open)
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/fastai/vision/image.py", line 398, in open_image
#     x = PIL.Image.open(fn).convert(convert_mode)
#   File "/gpfs/home/s4s004/vanstee/anaconda3/envs/powerai-fastai/lib/python3.7/site-packages/PIL/Image.py", line 2862, in open
#     "cannot identify image file %r" % (filename if filename else fp)
# PIL.UnidentifiedImageError: cannot identify image file '/gpfs/home/s4s004/vanstee/2020-07-utsa/aicoc-ai-immersion/UTSA/class_images/train/people_skateboarding/image(0004).jpeg'

# %%
learn.recorder.plot()

# %%
# Run 5 epochs (can do more if still getting better train / val)
# FILL IN THE RANGE BASE ON YOUR LRFIND RESULT
learn.fit_one_cycle(5, max_lr=slice(5e-5,1e-2))

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, if we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_top_losses(9, figsize=(19,11),heatmap=True)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
interp.confusion_matrix()

# %%
interp.most_confused(min_val=2)

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.save('stage-1')
learn.unfreeze()

# %%
learn.fit_one_cycle(5)

# %%
#learn.save('stage-2')
#learn.load('stage-1');
#learn.unfreeze(-2)
#learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-3))

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %% [markdown]
# ## Optional Assignment
# Can you redo the training above with a different pre-trained model ???  See this page for some ideas
#
# https://docs.fast.ai/vision.models.html
#
# * Hint : in a a code cell type  models.\<<tab\>>

# %%
doc(cnn_learner)

# %%
#learn = cnn_learner(data, FILL_IN_HERE!!, metrics=error_rate)
learn = cnn_learner(data, models.vgg11_bn, metrics=error_rate)
# model.alexnet

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(2) # 2 epochs ...

# %%
learn.save('stage-1-custom')

# %% [markdown]
# ## Lets continue to tune ...

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# If it doesn't get better results, you can always go back to your previous model.

# %%
learn.load('stage-1');

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)

# %% [markdown]
# # Advanced Example :  Loading Data from PAIV / IVI
#
# So you want to train on some data that maybe you labelled in another tool ?  No problem.  Here we show how you could read in data exported from PAIV and classifying in this tool ...
#
# For our IBM Visual Insights Example, we can just run a nice utility to reformat the output.  For convenience, we added a **Bananas Dataset** to our repo to play with ..

# %%
os.chdir(cfg["base_dir"])
# !ls *.zip

# %% [markdown]
# ## Unzip our bananas data and convert to images in sub-directories
#
# When you export data from IVI, you get a single zip file.  When you unzip this file, you get a singular directory with a metadata file called prop.json.  We have a utility that will read that prop.json and create a new directory with sorted images... lets see how this works

# %%
# unzip the Bananas.zip to /tmp/bananas_ivi directory
# !sudo yum install -y unzip
# !unzip -o -d /tmp Bananas.zip

# %%
# Now run our handy script !
# !git clone https://github.com/dustinvanstee/powerai-vision-utils.git

# %%
# !conda install -y scikit-learn # dependency to run our utility ..
# !python powerai-vision-utils/reorganize_exported_dataset.py --directory_in /tmp/Bananas --directory_out /tmp/bananas_fastai/train

# %%
# !ls /tmp/bananas_fastai/train

# %%
# New project config!
mycfg = {
    "image_dir" : "/tmp/bananas_fastai",
    "classes":["black","green","overripe","yellow","ripe"],  ## <<- CLASS Enter your search terms here 
    "d_partitions":["train"],
}
ivicfg=getconfig(mycfg)

# %%
# New Image Path ..
path = Path(ivicfg["image_dir"])
path

# %%
# !ls /tmp/bananas_fastai/black

# %% [markdown]
# ## Define Databunch

# %%
# Define some transforms and setup data bunch
tfms = get_transforms(do_flip=True)
data = ImageDataBunch.from_folder(path,train="train", ds_tfms=tfms, size=100, valid_pct=0.20)
data

# %%
# Display some images
data.show_batch(rows=3, figsize=(5,5))

# %% [markdown]
# ## Training

# %%
# Setup a CNN learner
learn = cnn_learner(data, models.resnet50, metrics=accuracy)
learn.fit_one_cycle(5)

# %%
# Learning rate search
learn.lr_find()

# %%
learn.recorder.plot()

# %%
# Run fit one cycle for 5 epochs
learn.fit_one_cycle(5,slice(7e-5,2e-2))

# %%
learn.fit_one_cycle(5,slice(7e-5,2e-2))

# %%
learn.fit_one_cycle(5,slice(7e-5,2e-2))

# %%
learn.fit_one_cycle(5,slice(7e-5,2e-2))

# %%
learn.fit_one_cycle(50,slice(7e-5,2e-2))

# %%
# Lets see how well we did ... 
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# # Inference

# %%
# Download some sample images here .... 
command = googliser + \
                      " --o /tmp/banana_inference "+\
                      " --phrase \"ripe black yellow green bananas\" " + \
                      " --parallel 50 --upper-size 500000 --lower-size 2000 " + \
                      " -n 10 " + \
                      " --format jpg --timeout 15 --safesearch-off "
print(command)
# !{command}

# %%
# get rid of malformed images manually .

command = cfg["jpeginfo"] + " -c /tmp/banana_inference"
# !{command}

#!ls /tmp/banana_inference
#!rm /tmp/banana_inference/image\(0020\).jpg

# %%
# Inference on your list of images .. 
import glob
files = glob.glob("/tmp/banana_inference/image*.jpg")

def single_inference(img_path) :
    
    img = open_image(img_path)
    prediction=learn.predict(img)
    #print(prediction)
    img_cls = data.classes[prediction[1].numpy()]
    img.show(title=img_cls)

for my_img in files :
    single_inference(my_img)

# %% [markdown]
# Congratulations, you can now build a pretty darn good classifier in less than one hour!
#
# Credits
# * FastAI Team
# * Bob Chesebrough / Dustin VanStee - AICoC Data science team
